# %% [markdown]
# # **Matplotlib**
#
# For each visualization, you have :
# * Many options
#   * Different plot types
#   * Many customizations (You can change colors, shapes, labels, axes, and so on)
# * Choice depends on :
#   * Data
#   * Story you want to tell

# %%
import matplotlib.pyplot as plt
year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]

plt.plot(year, pop)
plt.show()

# %%
plt.scatter(year, pop)
plt.show()

# %%
plt.plot(year, pop)
plt.scatter(year, pop)
plt.show()

# %%
plt.plot(year, pop)
plt.scatter(year, pop)

plt.xlabel('Year')
plt.ylabel('Population')
plt.title("World Population Projections")
plt.yticks([0, 2, 4, 6, 8, 10], # Manipulation number of y-axes
           ['0', '2B', '4B', '6B', '8B', '10B']) # Manipulation name of y-axes

plt.show()

# %% [markdown]
# ## **Histogram**
# * Explore dataset
# * Get idea about distribution

# %% [markdown]
# **x** should be a list of values you want to build a histogram for.
#
# **bins** to tell Python into how many bins the data should be divided.
#
# Based on this number, hist will automatically find appropriate boundaries for all bins, and calculate how may values are in each one. if you don't specify the bins argument, it will by 10 by default.

# %%
# help(plt.hist)

# %%
values = [0, 0.6, 1.4, 1.6, 2.2, 2.5, 2.6, 3.2, 3.5, 3.9, 4.2, 6]
plt.hist(values, bins=3)
plt.show()
